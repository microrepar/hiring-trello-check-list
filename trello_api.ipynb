# %%
from config import Config

# %%
# This code sample uses the 'requesid_board = '58984d438f2dc19d5daea3e7ts'' library:
# http://docs.python-requests.org
import requests

id_board = '58984d438f2dc19d5daea3e7'

url = f"https://api.trello.com/1/boards/{id_board}/labels"

query = {
  'key': Config.KEY_TRELLO,
  'token': Config.TOKEN_TRELLO
}

response = requests.request(
   "GET",
   url,
   params=query
)

from pprint import pprint

response.json()
# Out:
# [{'id': '5c2bb9286bf506324f87bc95',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'EDITAL Nº 13/2017',
#   'color': 'sky',
#   'uses': 183},
#  {'id': '5c2e4bfdfb5eea3e30a402ac',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'INDEFINIDO',
#   'color': 'yellow',
#   'uses': 155},
#  {'id': '5c2bb9041730b87826021475',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'EDITAL Nº 11/2015',
#   'color': 'orange',
#   'uses': 113},
#  {'id': '623ccbd62b7d7d3a19f0ffe1',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'EDITAL 04/2020',
#   'color': 'pink',
#   'uses': 108},
#  {'id': '5c65c40ea7f53a50182c455f',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'PROCESSO SELETIVO Nº 5/2018',
#   'color': 'pink',
#   'uses': 83},
#  {'id': '5c2bbad8a0696d3fd3a4c849',
#   'idBoard': '58984d438f2dc19d5daea3e7',
#   'name': 'EDITAL Nº 14/2017',
#   'color': 'green',
#   'uses': 81},
#  {'id': '5d27499b87d0be7c5431310c',
# ...

# %%
import redis

r = redis.Redis(
    host='redis-12502.c81.us-east-1-2.ec2.redns.redis-cloud.com',
    port=12502,
    decode_responses=True,
    username="default",
    password="Eq9IT06vo4wU6kUuVQFS0Oj9V3PQUI82",
)

success = r.set('foo', 'bar')
# True

result = r.get('foo')
print(result)
# >>> bar
# Out:
# bar

# %%
from pprint import pprint

result = r.hgetall('User')
pprint(result)
# Out:
# {'admin': '{"id": 1, "created_at": "2025-02-10", "updated_at": null, "status": '
#           '"active", "name": "admin", "age": null, "email": "", "username": '
#           '"admin", "password": '
#           '"$2b$12$//SPKhI8zXPl2AnsxcMgkOR7OxP538WBpqBnwgxSX5eItbbDb4ZOK", '
#           '"repeat_password": null}',
#  'admissao': '{"id": 2, "created_at": "2025-02-10", "updated_at": null, '
#              '"status": "active", "name": "admissao", "age": null, "email": '
#              '"admissao@pmmc.com.br", "username": "admissao", "password": '
#              '"$2b$12$KffZbUnme1TdiEQ5hOAV0ei8h0cRa1NGz6/yI8EOZCoY6AbIgB2ZC", '
#              '"repeat_password": null}'}
